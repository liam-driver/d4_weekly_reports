# %%
import pandas as pd
import datetime

# %%
df = pd.read_csv('weekly_reports', parse_dates=['Date'])
df['Date'] = pd.to_datetime(df['Date'])

# %%
yday = pd.Timestamp.now().date()
print(yday)
filt = (df['Paid / Organic'] == 'Paid') & (df['Date'] >= month_start) & (df['Date'] <= yday)
# Out:
# 2023-03-12
# ---------------------------------------------------------------------------
# InvalidComparison                         Traceback (most recent call last)
# File ~\PycharmProjects\Door4_Weekly_Reports\venv\Lib\site-packages\pandas\core\arrays\datetimelike.py:1054, in DatetimeLikeArrayMixin._cmp_method(self, other, op)
#    1053 try:
# -> 1054     other = self._validate_comparison_value(other)
#    1055 except InvalidComparison:
#
# File ~\PycharmProjects\Door4_Weekly_Reports\venv\Lib\site-packages\pandas\core\arrays\datetimelike.py:588, in DatetimeLikeArrayMixin._validate_comparison_value(self, other)
#     587 elif not is_list_like(other):
# --> 588     raise InvalidComparison(other)
#     590 elif len(other) != len(self):
#
# InvalidComparison: 2023-03-01
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 3
#       1 yday = pd.Timestamp.now().date()
# ...
